# %%
import pickle

# %%
with open(r"C:\Personal Storage\Workspace\Projects\Multimodal_RAG\raw_data_extracted\raw_pdf_elements.pkl", "rb") as f:
    raw_pdf_elements = pickle.load(f)

# %%
raw_pdf_elements

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# False
